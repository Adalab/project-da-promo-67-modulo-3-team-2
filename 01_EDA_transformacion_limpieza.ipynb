# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# %%
# Extracción de los datos iniciales
df = pd.read_csv('files/hr.csv')
df.head(5)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely       1102                   Sales
# 1  49.0        No  Travel_Frequently        279  Research & Development
# 2  37.0       Yes      Travel_Rarely       1373  Research & Development
# 3  33.0        No  Travel_Frequently       1392  Research & Development
# 4  27.0        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                    JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0         sALES eXECUTIVE               4.0        Single         5993.0
# 1      rESEARCH sCIENTIST               2.0       Married         5130.0
# 2   lABORATORY tECHNICIAN               3.0        Single         2090.0
# 3      rESEARCH sCIENTIST               3.0       Married         2909.0
# 4   lABORATORY tECHNICIAN               2.0       Married         3468.0
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1           80.0
# 1                  4                         4            NaN
# 2                  3                         2            NaN
# 3                  3                         3           80.0
# 4                  3                         4           80.0
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                    0.0
# 1                 1                 10                    3.0
# 2                 0                  7                    3.0
# 3                 0                  8                    3.0
# 4                 1                  6                    3.0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                   5.0
# 1                        1                   7.0
# 2                        0                   0.0
# 3                        3                   0.0
# 4                        2                   2.0

# %%
# Información de columnas y tipos de variables del dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1401 non-null   float64
#  1   Attrition                 1474 non-null   str
#  2   BusinessTravel            1357 non-null   str
#  3   DailyRate                 1474 non-null   int64
#  4   Department                1445 non-null   str
#  5   DistanceFromHome          1474 non-null   int64
#  6   Education                 1474 non-null   int64
#  7   EducationField            1416 non-null   str
#  8   EmployeeCount             1474 non-null   int64
#  9   EmployeeNumber            1474 non-null   int64
#  10  EnvironmentSatisfaction   1474 non-null   int64
#  11  Gender                    1474 non-null   str
#  12  HourlyRate                1474 non-null   int64
#  13  JobInvolvement            1474 non-null   int64
#  14  JobLevel                  1474 non-null   int64
#  15  JobRole                   1474 non-null   str
#  16  JobSatisfaction           1445 non-null   float64
#  17  MaritalStatus             1342 non-null   str
#  18  MonthlyIncome             1460 non-null   float64
#  19  MonthlyRate               1474 non-null   int64
#  20  NumCompaniesWorked        1474 non-null   int64
#  21  Over18                    1474 non-null   str
#  22  OverTime                  1430 non-null   str
#  23  PercentSalaryHike         1474 non-null   int64
#  24  PerformanceRating         1474 non-null   int64
#  25  RelationshipSatisfaction  1474 non-null   int64
#  26  StandardHours             1310 non-null   float64
#  27  StockOptionLevel          1474 non-null   int64
#  28  TotalWorkingYears         1474 non-null   int64
#  29  TrainingTimesLastYear     1386 non-null   float64
#  30  WorkLifeBalance           1474 non-null   int64
#  31  YearsAtCompany            1474 non-null   int64
#  32  YearsInCurrentRole        1474 non-null   int64
#  33  YearsSinceLastPromotion   1474 non-null   int64
#  34  YearsWithCurrManager      1326 non-null   float64
# dtypes: float64(6), int64(20), str(9)
# memory usage: 403.2 KB

# %%
# Comprobación de columnas y filas
df.shape
# Out:
# (1474, 35)

# %%
# Búsqueda de columnas con valores nulos
nulos = df.isnull().sum()
nulos = nulos[nulos>0]
nulos
# Out:
# Age                       73
# BusinessTravel           117
# Department                29
# EducationField            58
# JobSatisfaction           29
# MaritalStatus            132
# MonthlyIncome             14
# OverTime                  44
# StandardHours            164
# TrainingTimesLastYear     88
# YearsWithCurrManager     148
# dtype: int64

# %%
# Comprobación de porcentaje de nulos
nulos_pct = round(df.isnull().sum()/df.shape[0]*100, 2)
nulos_pct = nulos_pct[nulos_pct>0]
nulos_pct
# Out:
# Age                       4.95
# BusinessTravel            7.94
# Department                1.97
# EducationField            3.93
# JobSatisfaction           1.97
# MaritalStatus             8.96
# MonthlyIncome             0.95
# OverTime                  2.99
# StandardHours            11.13
# TrainingTimesLastYear     5.97
# YearsWithCurrManager     10.04
# dtype: float64

# %%
# Comprobación de duplicados y verificacióin de que los numeros de empleados están repetidos
print(df.duplicated().sum())
print(df['EmployeeNumber'].duplicated().sum())
# Out:
# 4
# 4

# %%
# Visualización de las filas con EmployeeNumber duplicado
# y se ordenan por EmployeeNumber para ver juntas las repeticiones
df[df['EmployeeNumber'].duplicated(keep=False)].sort_values('EmployeeNumber')
# Out:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 67    45.0        No  Travel_Rarely       1339  Research & Development
# 1473  45.0        No  Travel_Rarely       1339  Research & Development
# 1471  53.0        No  Travel_Rarely       1084  Research & Development
# 184   53.0        No  Travel_Rarely       1084  Research & Development
# 1470  28.0        No  Travel_Rarely        866                   Sales
# 1041  28.0        No  Travel_Rarely        866                   Sales
# 1222  24.0       Yes  Travel_Rarely        240         Human Resources
# 1472  24.0       Yes  Travel_Rarely        240         Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 67                   7          3    Life Sciences              1
# 1473                 7          3    Life Sciences              1
# 1471                13          2          Medical              1
# 184                 13          2          Medical              1
# 1470                 5          3          Medical              1
# 1041                 5          3          Medical              1
# 1222                22          1  Human Resources              1
# 1472                22          1  Human Resources              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 67                86                        2    Male          59
# 1473              86                        2    Male          59
# 1471             250                        4  Female          57
# 184              250                        4  Female          57
# 1470            1469                        4    Male          84
# 1041            1469                        4    Male          84
# 1222            1714                        4    Male          58
# 1472            1714                        4    Male          58
#
#       JobInvolvement  JobLevel                   JobRole  JobSatisfaction  \
# 67                 3         3       rESEARCH sCIENTIST               1.0
# 1473               3         3       rESEARCH sCIENTIST               1.0
# 1471               4         2   mANUFACTURING dIRECTOR               1.0
# 184                4         2   mANUFACTURING dIRECTOR               1.0
# 1470               3         2          sALES eXECUTIVE               1.0
# 1041               3         2          sALES eXECUTIVE               1.0
# 1222               1         1          hUMAN rESOURCES               3.0
# 1472               1         1          hUMAN rESOURCES               3.0
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 67        Divorced         9724.0        18787                   2      Y
# 1473      Divorced         9724.0        18787                   2      Y
# 1471      Divorced         4450.0        26250                   1      Y
# 184       Divorced         4450.0        26250                   1      Y
# 1470        Single         8463.0        23490                   0      Y
# 1041        Single         8463.0        23490                   0      Y
# 1222       Married         1555.0        11585                   1      Y
# 1472       Married         1555.0        11585                   1      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 67         No                 17                  3                         3
# 1473       No                 17                  3                         3
# 1471       No                 11                  3                         3
# 184        No                 11                  3                         3
# 1470       No                 18                  3                         4
# 1041       No                 18                  3                         4
# 1222       No                 11                  3                         3
# 1472       No                 11                  3                         3
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 67              NaN                 1                 25
# 1473            NaN                 1                 25
# 1471            NaN                 2                  5
# 184             NaN                 2                  5
# 1470            NaN                 0                  6
# 1041            NaN                 0                  6
# 1222           80.0                 1                  1
# 1472           80.0                 1                  1
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 67                      2.0                3               1
# 1473                    2.0                3               1
# 1471                    3.0                3               4
# 184                     3.0                3               4
# 1470                    4.0                3               5
# 1041                    4.0                3               5
# 1222                    2.0                3               1
# 1472                    2.0                3               1
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 67                     0                        0                   0.0
# 1473                   0                        0                   0.0
# 1471                   2                        1                   3.0
# 184                    2                        1                   3.0
# 1470                   4                        1                   NaN
# 1041                   4                        1                   NaN
# 1222                   0                        0                   0.0
# 1472                   0                        0                   0.0

# %%
# Verificación de si existen valores negativos en el dataset
(df.select_dtypes(include='number') < 0).any().any()
# Out:
# np.False_

# %% [markdown]
# **Comprobaciones realizadas:**
#
# * Los títulos de columnas siguen la misma estética.
# * `JobRol` tiene los textos con las mayúsculas invertidas.
# * `BusinessTravel` tiene guión bajo como separación en vez de espacios.
# * Hay 4 filas duplicadas. Se confirma con el número de empleado.
# * No hay números negativos en ninguna columna.
#
# **Tareas pendientes:**
#
# - [_] Cambiar `JobRol`y `BusinessTravel` para continuidad de la estética
# - [_] Eliminación de duplicados.

# %%
# Se comprueba que los valores de Attrition sean solo "Yes" o "No". No tiene nulos
df['Attrition'].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
# Education es un valor numérico que mide la escala de estudios, se comprueba los valores comprendidos. No tiene nulos
df['Education'].unique()
# Out:
# array([2, 1, 4, 3, 5])

# %%
# Solo debe devolver valor "1". No aporta valor
df['EmployeeCount'].unique()
# Out:
# array([1])

# %%
# Encuesta de satisfacción. Escala de valores entre 1 y 4. No tiene nulos
df['EnvironmentSatisfaction'].unique()
# Out:
# array([2, 3, 4, 1])

# %%
# Se comprueba que haya solo dos valores. No tiene nulos
df['Gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
# Encuesta de satisfacción. Escala de valores entre 1 y 4. No tiene nulos
df['JobInvolvement'].unique()
# Out:
# array([3, 2, 4, 1])

# %%
# Jerarquía de la empresa. Valores entre 1 y 5. No tiene nulos
df['JobLevel'].unique()
# Out:
# array([2, 1, 3, 4, 5])

# %%
# Encuesta de satisfacción. Escala de valores entre 1 y 4. Tiene nulos
df['JobSatisfaction'].unique()
# Out:
# array([ 4.,  2.,  3.,  1., nan])

# %%
# Comprobación de que solo existan cuatro valores y nulos
df['MaritalStatus'].unique()
# Out:
# <StringArray>
# ['Single', 'Married', 'Divorced', nan, 'Marreid']
# Length: 5, dtype: str

# %%
# Comprobación del número de valores
df['NumCompaniesWorked'].unique()
# Out:
# array([8, 1, 6, 9, 0, 4, 5, 2, 7, 3])

# %%
# Todos los valores en "Y"
df['Over18'].unique()
# Out:
# <StringArray>
# ['Y']
# Length: 1, dtype: str

# %%
# Comprobación de valores, "yes" o "no". Tiene nulos
df['OverTime'].unique()
# Out:
# <StringArray>
# ['Yes', 'No', nan]
# Length: 3, dtype: str

# %%
# Valor de empresa respecto al empleado. Escala de valores entre 1 y 4, pero solo aparecen dos 
df['PerformanceRating'].unique()
# Out:
# array([3, 4])

# %%
# Encuesta de satisfacción. Escala de valores entre 1 y 4. Sin nulos
df['RelationshipSatisfaction'].unique()
# Out:
# array([1, 4, 2, 3])

# %%
# Jornada Laboral. Solo presenta dos valores: nulos o 80
df['StandardHours'].unique()
# Out:
# array([80., nan])

# %%
# Valores entre 0 y 3. Valor 0 indica sin acciones. Valor 1 nivel alto de acciones. Valor 2 nivel medio de acciones. Valor 3 nivel bajo de acciones
df['StockOptionLevel'].unique()
# Out:
# array([0, 1, 3, 2])

# %%
# Valor de formaciones que se ha recibido en el último año. Escala de valores entre 0 y 6. Con nulos
df['TrainingTimesLastYear'].unique()
# Out:
# array([ 0.,  3.,  2.,  5.,  1.,  4., nan,  6.])

# %%
# Encuesta de satisfacción. Escala de valores entre 1 y 4. Sin nulos
df['WorkLifeBalance'].unique()
# Out:
# array([1, 3, 2, 4])

# %% [markdown]
# **Se identifican las siguientes cuestiones:**
#
# * Las columnas `Attrition`, `Over18` y `OverTime` son valores booleanos en STR. No siguen el mismo formato.
# * Las columnas `EmployeeCount`, `Over18`, `PerformanceRating` y `StandardHours` no aportan valor claro al estudio. Es necesario determinar si se descartan valores o se quieren conservar.
# * Hay columnas en float que deben pasar a INT: `Age`, `JobSatisfaction`, `StandardHours`, `TrainingTimesLastYear` y `YearsWithCurrManager`.
# * Se comprueba que las columnas con encuestas de satisfacción siempre tienen valores del 1 al 4.
# * Se encuentra una errata en los valores de `MaritalStatus`.
#
# **Tareas pendientes:**
#
# - [_] Eliminar las columnas que no aportan valor al estudio. Se decide eliminar: `EmployeeCount`, `Over18` y `StandardHours`. `PerformanceRating` se mantiene para posibles estudios posteriores.
# - [_] Cambiar los tipos de columnas: `Age`, `JobSatisfaction`, `StandardHours`, `TrainingTimesLastYear` y `YearsWithCurrManager`a Int64 y `Attrition` y `OverTime` a booleano.
# - [_] Ajustar los valores de la columna `MaritalStatus`.
# - [_] Usar `EmployeeNumber` como índice del dataset.

# %% [markdown]
# ## Limpieza y transformación de datos

# %%
#Convertimos la columna Age a número entero
## Usamos Int64 en vez de int porque Age tiene valores nulos
# El tipo Int64 permite trabajar con enteros y mantener los nulos como <NA>
df['Age'] = df['Age'].astype('Int64')
df['Age'].dtype
# Out:
# Int64Dtype()

# %%
#Convertimos la columna JobSatisfaction a número entero
## Usamos Int64 en vez de int porque JobSatisfaction tiene valores nulos
# El tipo Int64 permite trabajar con enteros y mantener los nulos como <NA>
df['JobSatisfaction'] = df['JobSatisfaction'].astype('Int64')
df['JobSatisfaction'].dtype
# Out:
# Int64Dtype()

# %%
#Convertimos la columna StandardHours a número entero, aunque se contempla el descarte
## Usamos Int64 en vez de int porque StandardHours tiene valores nulos
# El tipo Int64 permite trabajar con enteros y mantener los nulos como <NA>
df['StandardHours'] = df['StandardHours'].astype('Int64')
df['StandardHours'].dtype
# Out:
# Int64Dtype()

# %%
#Convertimos la columna TrainingTimesLastYear a número entero
## Usamos Int64 en vez de int porque TrainingTimesLastYear tiene valores nulos
# El tipo Int64 permite trabajar con enteros y mantener los nulos como <NA>
df['TrainingTimesLastYear'] = df['TrainingTimesLastYear'].astype('Int64')
df['TrainingTimesLastYear'].dtype
# Out:
# Int64Dtype()

# %%
#Convertimos la columna YearsWithCurrManager a número entero
## Usamos Int64 en vez de int porque YearsWithCurrManager tiene valores nulos
# El tipo Int64 permite trabajar con enteros y mantener los nulos como <NA>
df['YearsWithCurrManager'] = df['YearsWithCurrManager'].astype('Int64')
df['YearsWithCurrManager'].dtype
# Out:
# Int64Dtype()

# %%
# Convertimos JobRole a título y eliminamos espacios sobrantes al principio y al final de cada valor
df['JobRole'] = df['JobRole'].str.strip().str.title()
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single         5993.0
# 1     Research Scientist                2       Married         5130.0
# 2  Laboratory Technician                3        Single         2090.0
# 3     Research Scientist                3       Married         2909.0
# 4  Laboratory Technician                2       Married         3468.0
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4           <NA>
# 2                  3                         2           <NA>
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
# Cambiamos guiones bajos de BusinessTrave por espacios
df['BusinessTravel'] = df['BusinessTravel'].str.replace("_", " ")
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel Rarely       1102                   Sales
# 1   49        No  Travel Frequently        279  Research & Development
# 2   37       Yes      Travel Rarely       1373  Research & Development
# 3   33        No  Travel Frequently       1392  Research & Development
# 4   27        No      Travel Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single         5993.0
# 1     Research Scientist                2       Married         5130.0
# 2  Laboratory Technician                3        Single         2090.0
# 3     Research Scientist                3       Married         2909.0
# 4  Laboratory Technician                2       Married         3468.0
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4           <NA>
# 2                  3                         2           <NA>
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
# Convertimos la columna Attrition a valores booleanos
# 'Yes' se transforma en True
# 'No' se transforma en False
df['Attrition'] = df['Attrition'].map({
    'Yes': True,
    'No': False
}).astype('boolean')
df['Attrition'].unique()
# Out:
# <BooleanArray>
# [True, False]
# Length: 2, dtype: boolean

# %%
# Comprobación del tipo final
df['Attrition'].dtype
# Out:
# BooleanDtype

# %%
# Convertimos la columna OverTime a valores booleanos
# 'Yes' se transforma en True
# 'No' se transforma en False
df['OverTime'] = df['OverTime'].map({'Yes': True, 'No': False}).astype('boolean')

# %%
# Comprobación del tipo final
df['OverTime'].dtype
# Out:
# BooleanDtype

# %%
# Eliminamos las filas completamente duplicadas
df = df.drop_duplicates(keep='first')
print(df.duplicated().sum())
# Out:
# 0

# %%
# Eliminación de las columnas que no aportan valor al estudio
df.drop(columns=['EmployeeCount' , 'Over18', 'StandardHours'], inplace=True)

# %%
# EmployeeNumber identifica de forma única a cada empleado/a,
# por lo que lo usamos como índice del dataframe.
df = df.set_index('EmployeeNumber')

# %%
# Eliminación de la errata localizada
df['MaritalStatus'] = df['MaritalStatus'].replace('Marreid', 'Married')

# %%
# Comprobación de los valores actuales
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     606
# Single      436
# Divorced    296
# Name: count, dtype: int64

# %%
# Visualización final del dataset
df.head(10)
# Out:
#                 Age  Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       True      Travel Rarely       1102
# 2                49      False  Travel Frequently        279
# 4                37       True      Travel Rarely       1373
# 5                33      False  Travel Frequently       1392
# 7                27      False      Travel Rarely        591
# 8                32      False  Travel Frequently       1005
# 10               59      False      Travel Rarely       1324
# 11               30      False      Travel Rarely       1358
# 12               38      False  Travel Frequently        216
# 13               36      False      Travel Rarely       1299
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
# 8               Research & Development                 2          2
# 10              Research & Development                 3          3
# 11                                 NaN                24          1
# 12              Research & Development                23          3
# 13              Research & Development                27          3
#
#                EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# EmployeeNumber
# 1               Life Sciences                        2  Female          94
# 2               Life Sciences                        3    Male          61
# 4                       Other                        4    Male          92
# 5               Life Sciences                        4  Female          56
# 7                     Medical                        1    Male          40
# 8               Life Sciences                        4    Male          79
# 10                    Medical                        3  Female          81
# 11              Life Sciences                        4    Male          67
# 12              Life Sciences                        4    Male          44
# 13                        NaN                        3    Male          94
#
#                 JobInvolvement  JobLevel                    JobRole  \
# EmployeeNumber
# 1                            3         2            Sales Executive
# 2                            2         2         Research Scientist
# 4                            2         1      Laboratory Technician
# 5                            3         1         Research Scientist
# 7                            3         1      Laboratory Technician
# 8                            3         1      Laboratory Technician
# 10                           4         1      Laboratory Technician
# 11                           3         1      Laboratory Technician
# 12                           2         3     Manufacturing Director
# 13                           3         2  Healthcare Representative
#
#                 JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# EmployeeNumber
# 1                             4        Single         5993.0        19479
# 2                             2       Married         5130.0        24907
# 4                             3        Single         2090.0         2396
# 5                             3       Married         2909.0        23159
# 7                             2       Married         3468.0        16632
# 8                             4        Single         3068.0        11864
# 10                            1       Married         2670.0         9964
# 11                            3      Divorced         2693.0        13335
# 12                            3        Single         9526.0         8787
# 13                            3       Married         5237.0        16577
#
#                 NumCompaniesWorked  OverTime  PercentSalaryHike  \
# EmployeeNumber
# 1                                8      True                 11
# 2                                1     False                 23
# 4                                6      True                 15
# 5                                1      True                 11
# 7                                9     False                 12
# 8                                0     False                 13
# 10                               4      <NA>                 20
# 11                               1     False                 22
# 12                               0     False                 21
# 13                               6     False                 13
#
#                 PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# EmployeeNumber
# 1                               3                         1                 0
# 2                               4                         4                 1
# 4                               3                         2                 0
# 5                               3                         3                 0
# 7                               3                         4                 1
# 8                               3                         3                 0
# 10                              4                         1                 3
# 11                              4                         2                 1
# 12                              4                         2                 0
# 13                              3                         2                 2
#
#                 TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeNumber
# 1                               8                      0                1
# 2                              10                      3                3
# 4                               7                      3                3
# 5                               8                      3                3
# 7                               6                      3                3
# 8                               8                      2                2
# 10                             12                      3                2
# 11                              1                      2                3
# 12                             10                      2                3
# 13                             17                      3                2
#
#                 YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1                            6                   4                        0
# 2                           10                   7                        1
# 4                            0                   0                        0
# 5                            8                   7                        3
# 7                            2                   2                        2
# 8                            7                   7                        3
# 10                           1                   0                        0
# 11                           1                   0                        0
# 12                           9                   7                        1
# 13                           7                   7                        7
#
#                 YearsWithCurrManager
# EmployeeNumber
# 1                                  5
# 2                                  7
# 4                                  0
# 5                                  0
# 7                                  2
# 8                                  6
# 10                              <NA>
# 11                                 0
# 12                                 8
# 13                              <NA>

# %% [markdown]
# **Tareas finalizadas**:
#
# - [x] Cambiar `JobRol`y `BusinessTravel` para continuidad de la estética
# - [x] Eliminación de duplicados.
# - [x] Eliminar las columnas que no aportan valor al estudio. Se decide eliminar: `EmployeeCount`, `Over18` y `StandardHours`. `PerformanceRating` se mantiene para posibles estudios posteriores.
# - [x] Cambiar los tipos de columnas: `Age`, `JobSatisfaction`, `StandardHours`, `TrainingTimesLastYear` y `YearsWithCurrManager`a Int64 y `Attrition` y `OverTime` a booleano.
# - [x] Ajustar los valores de la columna `MaritalStatus`.
# - [x] Usar `EmployeeNumber` como índice del dataset.

# %% [markdown]
# **Análisis de los nulos:**
#
# * Se comprueba que no hay columnas con nulos superiores al 25%, aun así se decide automatizar el proceso considerando dichos valores por posibles estudios futuros con un dataset diferente.
# * Se verifica que ninguna columna necesita imputación fuera de las reglas habituales.
#
# **Tareas pendientes**:
#
# - [_] Imputación de nulos, según el tipo de columna y los valores.

# %%
# Comprobación de tipos correctos en todas las columnas. Gestión de nulos pendientes
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1470 entries, 1 to 2068
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1397 non-null   Int64
#  1   Attrition                 1470 non-null   boolean
#  2   BusinessTravel            1353 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1441 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1412 non-null   str
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   str
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   str
#  14  JobSatisfaction           1441 non-null   Int64
#  15  MaritalStatus             1338 non-null   str
#  16  MonthlyIncome             1456 non-null   float64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1426 non-null   boolean
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1382 non-null   Int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1323 non-null   Int64
# dtypes: Int64(4), boolean(2), float64(1), int64(18), str(6)
# memory usage: 356.0 KB

# %%
# Función para gestión de nulos de las columnas categóricas
def sustitucion_nulos_categoricas(df):
    # Copia del DF para evitar suscribir los datos en el original
    df = df.copy()
    # Selección de las columnas categóricas
    columnas_categoricas = df.select_dtypes(include='object').columns
    # Filtrado de las columnas con nulos
    columnas_con_nulos = [col for col in columnas_categoricas if df[col].isnull().sum() > 0]
    for columna in columnas_con_nulos:
        porcentaje_nulos = df[columna].isnull().sum()/df.shape[0]*100
        print(f"{columna}. Nulos antes = {df[columna].isnull().sum()} ({porcentaje_nulos:.1f}%)")

        # Búsqueda del valor dominante en la columna
        lista_valores = df[columna].value_counts()/df.shape[0]*100
        dominante = lista_valores.iloc[0]

        # Acción para valores por encima de 25% se imputa con la moda
        if porcentaje_nulos > 25:
            df[columna] = df[columna].fillna(lista_valores.index[0])
            print(f"{columna}. Nulos después = {df[columna].isnull().sum()}")

        # Por debajo de 25% se comprueba la dominancia
        else:
            print(f"{columna}. Dominante = {dominante:.1f}%")
            
            # Si la categoría dominante es inferior al 75% creamos una nueva categoría
            if dominante <= 75:
                df[columna] = df[columna].fillna('unknown')
                print(f"{columna}. Nulos después = {df[columna].isnull().sum()}")

            # Si la categoría dominante es superior al 75% se imputa con la moda    
            else:
                df[columna] = df[columna].fillna(lista_valores.index[0])
                print(f"{columna}. Nulos después = {df[columna].isnull().sum()}")

    return df

# %%
# Ejecución de la función e imputación de las columnas categóricas
df_cat_limpio = sustitucion_nulos_categoricas(df)
df_cat_limpio.sample(5)
# Out:
# BusinessTravel. Nulos antes = 117 (8.0%)
# BusinessTravel. Dominante = 64.7%
# BusinessTravel. Nulos después = 0
# Department. Nulos antes = 29 (2.0%)
# Department. Dominante = 63.9%
# Department. Nulos después = 0
# EducationField. Nulos antes = 58 (3.9%)
# EducationField. Dominante = 39.5%
# EducationField. Nulos después = 0
# MaritalStatus. Nulos antes = 132 (9.0%)
# MaritalStatus. Dominante = 41.2%
# MaritalStatus. Nulos después = 0
#                 Age  Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1648             27      False  Travel Frequently        591
# 869              28      False      Travel Rarely       1169
# 1592             23      False      Travel Rarely        977
# 714              27      False  Travel Frequently       1410
# 657              20      False      Travel Rarely        959
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1648            Research & Development                 2          3
# 869                    Human Resources                 8          2
# 1592            Research & Development                10          3
# 714                              Sales                 3          1
# 657             Research & Development                 1          3
#
#                   EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# EmployeeNumber
# 1648                     Medical                        4    Male          87
# 869                      Medical                        2    Male          63
# 1592            Technical Degree                        4    Male          45
# 714                      Medical                        4  Female          71
# 657                Life Sciences                        4  Female          83
#
#                 JobInvolvement  JobLevel             JobRole  JobSatisfaction  \
# EmployeeNumber
# 1648                         3         1  Research Scientist                4
# 869                          2         1     Human Resources                4
# 1592                         4         1  Research Scientist                3
# 714                          4         2     Sales Executive                4
# 657                          2         1  Research Scientist                2
#
#                MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# EmployeeNumber
# 1648                  Single         2580.0         6297                   2
# 869                 Divorced         4936.0        23965                   1
# 1592                 Married         2073.0        12826                   2
# 714                 Divorced         4647.0        16673                   1
# 657                   Single         2836.0        11757                   1
#
#                 OverTime  PercentSalaryHike  PerformanceRating  \
# EmployeeNumber
# 1648               False                 13                  3
# 869                False                 13                  3
# 1592               False                 16                  3
# 714                 True                 20                  4
# 657                False                 13                  3
#
#                 RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# EmployeeNumber
# 1648                                   3                 0                  6
# 869                                    4                 1                  6
# 1592                                   4                 1                  4
# 714                                    2                 2                  6
# 657                                    4                 0                  1
#
#                 TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# EmployeeNumber
# 1648                                0                2               4
# 869                                 6                3               5
# 1592                             <NA>                3               2
# 714                                 3                3               6
# 657                                 0                4               1
#
#                 YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1648                             2                        1
# 869                              1                        0
# 1592                             2                        2
# 714                              5                        0
# 657                              0                        0
#
#                 YearsWithCurrManager
# EmployeeNumber
# 1648                               2
# 869                                4
# 1592                               2
# 714                                4
# 657                                0

# %%
# Función para gestión de nulos de las columnas booleanas
def sustitucion_nulos_booleanas(df):
    # Copia del DF para evitar suscribir los datos en el original
    df = df.copy()
    # Selección de las columnas booleanas
    columnas_bool = df.select_dtypes(include='boolean').columns
    # Filtrado de columnas con nulos
    columnas_con_nulos = [col for col in columnas_bool if df[col].isnull().sum() > 0]

    for columna in columnas_con_nulos:
        moda = df[columna].mode()[0]
        print(f"{columna}: nulos antes = {df[columna].isnull().sum()}. Se sustituye con la moda: ({moda})")
        # Imputación con la moda
        df[columna] = df[columna].fillna(moda)

    return df

# %%
# Ejecución de la función e imputación de las columnas booleanas
df_bool_limpio = sustitucion_nulos_booleanas(df_cat_limpio)
df_bool_limpio.sample(5)
# Out:
# OverTime: nulos antes = 44. Se sustituye con la moda: (False)
#                 Age  Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 1423             58      False  Travel Rarely       1055
# 303              54      False  Travel Rarely       1147
# 667              27       True  Travel Rarely       1420
# 98               31      False  Travel Rarely        746
# 1268             33      False        unknown        536
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1423            Research & Development                 1          3
# 303                              Sales                 3          3
# 667                              Sales                 2          1
# 98              Research & Development                 8          4
# 1268                             Sales                10          5
#
#                EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# EmployeeNumber
# 1423                  Medical                        4  Female          76
# 303                 Marketing                        4  Female          52
# 667                 Marketing                        3    Male          85
# 98              Life Sciences                        3  Female          61
# 1268                Marketing                        4    Male          82
#
#                 JobInvolvement  JobLevel                 JobRole  \
# EmployeeNumber
# 1423                         3         5       Research Director
# 303                          3         2         Sales Executive
# 667                          3         1    Sales Representative
# 98                           3         2  Manufacturing Director
# 1268                         4         3         Sales Executive
#
#                 JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# EmployeeNumber
# 1423                          1       Married        19701.0        22456
# 303                           1       Married         5940.0        17011
# 667                           1      Divorced         3041.0        16346
# 98                            4        Single         4424.0        20682
# 1268                          3      Divorced         8380.0        21708
#
#                 NumCompaniesWorked  OverTime  PercentSalaryHike  \
# EmployeeNumber
# 1423                             3      True                 21
# 303                              2     False                 14
# 667                              0     False                 11
# 98                               1     False                 23
# 1268                             0      True                 14
#
#                 PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# EmployeeNumber
# 1423                            4                         3                 1
# 303                             3                         4                 1
# 667                             3                         2                 1
# 98                              4                         4                 0
# 1268                            3                         4                 2
#
#                 TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeNumber
# 1423                           32                      3                3
# 303                            16                      4                3
# 667                             5                      3                3
# 98                             11                      2                3
# 1268                           10                      3                3
#
#                 YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 1423                         9                   8                        1
# 303                          6                   2                        0
# 667                          4                   3                        0
# 98                          11                   7                        1
# 1268                         9                   8                        0
#
#                 YearsWithCurrManager
# EmployeeNumber
# 1423                               5
# 303                                5
# 667                                2
# 98                                 8
# 1268                               8

# %%
# Función para gestión de nulos de las columnas numéricas
def sustitucion_nulos_numericas(df):
    # Copia del DF para evitar suscribir los datos en el original
    df = df.copy()
    # Selección de las columnas numéricas
    columnas_numericas = df.select_dtypes(include=['number']).columns
    # Filtrado de columnas con nulos
    columnas_con_nulos = [col for col in columnas_numericas if df[col].isnull().sum() > 0]
    # Entrenamiento del imputador
    imputador = IterativeImputer(max_iter= 10, random_state= 42)
    valores_imputados = imputador.fit_transform(df[columnas_numericas])
    df_temp = pd.DataFrame(valores_imputados, columns=columnas_numericas, index=df.index)
    
    for columna in columnas_con_nulos:
        porcentaje_nulos = df[columna].isnull().sum()/df.shape[0]*100
        print(f"{columna}. Nulos antes = {df[columna].isnull().sum()} ({porcentaje_nulos:.1f}%)")

        # En nulos superiores a un 25% se sustituye con valores del imputador
        if porcentaje_nulos > 25:
            df[columna] = df_temp[columna]
            print(f"{columna}. Nulos después = {df[columna].isnull().sum()}")

        # En nulos inferiores a un 25% se considera si hay sesgo entre media y mediana
        else:
            sesgo = df[columna].skew()
            mediana = df[columna].median()
            media = df[columna].mean() 
            print(f"{columna}. Sesgo = {sesgo:.2f}")

            # Para sesgos superiores a un 0.5 se imputa con la mediana
            if abs(sesgo) > 0.5:
                df[columna] = df[columna].fillna(round(mediana))
                print(f"{columna}. Nulos después = {df[columna].isnull().sum()}")
                
            # Para sesgos inferiores a un 0.5 se imputa con la media
            else:
                df[columna] = df[columna].fillna(round(media))
                print(f"{columna}. Nulos después = {df[columna].isnull().sum()}")

    return df

# %%
# Ejecución de la función e imputación de las columnas numéricas
df_limpio = sustitucion_nulos_numericas(df_bool_limpio)
df_limpio.sample(5)
# Out:
# Age. Nulos antes = 73 (5.0%)
# Age. Sesgo = 0.41
# Age. Nulos después = 0
# JobSatisfaction. Nulos antes = 29 (2.0%)
# JobSatisfaction. Sesgo = -0.33
# JobSatisfaction. Nulos después = 0
# MonthlyIncome. Nulos antes = 14 (1.0%)
# MonthlyIncome. Sesgo = 1.37
# MonthlyIncome. Nulos después = 0
# TrainingTimesLastYear. Nulos antes = 88 (6.0%)
# TrainingTimesLastYear. Sesgo = 0.55
# TrainingTimesLastYear. Nulos después = 0
# YearsWithCurrManager. Nulos antes = 147 (10.0%)
# YearsWithCurrManager. Sesgo = 0.85
# YearsWithCurrManager. Nulos después = 0
#                 Age  Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 401              26       True      Travel Rarely        950
# 497              27      False            unknown       1469
# 806              30      False      Travel Rarely        921
# 478              21       True  Travel Frequently        756
# 281              40      False            unknown        905
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 401                              Sales                 4          4
# 497             Research & Development                 1          2
# 806             Research & Development                 1          3
# 478                              Sales                 1          1
# 281             Research & Development                19          2
#
#                   EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# EmployeeNumber
# 401                    Marketing                        4    Male          48
# 497                      Medical                        4    Male          82
# 806                Life Sciences                        4    Male          38
# 478             Technical Degree                        1  Female          99
# 281                      Medical                        3    Male          99
#
#                 JobInvolvement  JobLevel                JobRole  \
# EmployeeNumber
# 401                          2         2        Sales Executive
# 497                          3         1  Laboratory Technician
# 806                          1         1  Laboratory Technician
# 478                          2         1   Sales Representative
# 281                          3         2  Laboratory Technician
#
#                 JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# EmployeeNumber
# 401                           4        Single         5828.0         8450
# 497                           2      Divorced         3816.0        17881
# 806                           3       Married         3833.0        24375
# 478                           2        Single         2174.0         9150
# 281                           4       Married         2741.0        16523
#
#                 NumCompaniesWorked  OverTime  PercentSalaryHike  \
# EmployeeNumber
# 401                              1      True                 12
# 497                              1     False                 11
# 806                              3     False                 21
# 478                              1      True                 11
# 281                              8      True                 15
#
#                 PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# EmployeeNumber
# 401                             3                         2                 0
# 497                             3                         2                 1
# 806                             4                         3                 2
# 478                             3                         3                 0
# 281                             3                         3                 1
#
#                 TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeNumber
# 401                             8                      0                3
# 497                             5                      2                3
# 806                             7                      2                3
# 478                             3                      3                3
# 281                            15                      2                4
#
#                 YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# 401                          8                   7                        7
# 497                          5                   2                        0
# 806                          2                   2                        0
# 478                          3                   2                        1
# 281                          7                   2                        3
#
#                 YearsWithCurrManager
# EmployeeNumber
# 401                                4
# 497                                4
# 806                                2
# 478                                2
# 281                                7

# %%
# Verificación de que no existen nulos en el dataset
df_limpio.isnull().any().any()
# Out:
# np.False_

# %%
# Última comprobación de la información del dataset
df_limpio.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1470 entries, 1 to 2068
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   Int64
#  1   Attrition                 1470 non-null   boolean
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   str
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   str
#  14  JobSatisfaction           1470 non-null   Int64
#  15  MaritalStatus             1470 non-null   str
#  16  MonthlyIncome             1470 non-null   float64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   boolean
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   Int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   Int64
# dtypes: Int64(4), boolean(2), float64(1), int64(18), str(6)
# memory usage: 356.0 KB

# %% [markdown]
# ## Creación de csv final limpio:
#
# Tras la transformación y limpieza, el dataset está listo para la fase de análisis estadístico y visualización.
# Datos finales:
#
# * Filas: 1474
# * Columnas: 35
# * Nulos: 0
# * Duplicados: 0
#
# Con estos datos, se crea un nuevo CSV con los valores transformados

# %%
# Creación del csv limpio
df_limpio.to_csv('files/hr_final.csv')
